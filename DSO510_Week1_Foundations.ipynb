# %% [markdown]
# <a href="https://colab.research.google.com/github/sashapisterman/DSO510-Business-Analytics/blob/main/DSO510_Week1_Foundations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DSO 510 — Business Analytics
# ## Week 1: Python Foundations
# **Author:** Sasha Pisterman
# **Date:** June 1, 2026
# **Purpose:** Introduction to Python syntax, Google Colab, and notebook structure.

# %%
print("Hello, world!")
# Out:
# Hello, world!

# %%
print("My name is Sasha")
# Out:
# My name is Sasha

# %%
sample_size = 250
print(sample_size)
# Out:
# 250

# %% [markdown]
# ## Variables
# These variables store key metadata from the vibe coding content analysis project (CMGT 514).
# Sample consisted of 150 units collected from YouTube and Reddit.

# %%
# Variables from the vibe coding project
sample_size = 150
platform_count = 2
negative_sentiment = 0.46
positive_sentiment = 0.14
project_title = "Public Discourse Around Vibe Coding"
published = False

# %%
print(sample_size)
print(platform_count)
print(negative_sentiment)
print (positive_sentiment)
print(project_title)
print(published)
# Out:
# 150
# 2
# 0.46
# 0.14
# Public Discourse Around Vibe Coding
# False

# %% [markdown]
# ## Project Summary Output
# Printing a readable summary of project metadata using f-strings.

# %%
print(f"Project: {project_title}")
print(f"Total units analyzed: {sample_size}")
print(f"Number of platforms: {platform_count}")
print(f"Negative sentiment rate: {negative_sentiment}")
print(f"Positive sentiment rate: {positive_sentiment}")
print(f"Published: {published}")
# Out:
# Project: Public Discourse Around Vibe Coding
# Total units analyzed: 150
# Number of platforms: 2
# Negative sentiment rate: 0.46
# Positive sentiment rate: 0.14
# Published: False
